# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', 500)
data_frame = pd.read_csv('./jobs.csv')
data_frame
# Out:
#                            _id  \
# 0     6447d95de5702a9c751c8d21
# 1     61b1b3b774413e0016d4e7f1
# 2     62454da3653261babad65676
# 3     62454d9e653261babad6566e
# 4     62454d92653261babad6565d
# ...                        ...
# 2352  64138b6254e25834e3659ad4
# 2353  641474e1968597fb11a0a9df
# 2354  64147677968597fb11a0a9f6
# 2355  641479c2968597fb11a0aa1d
# 2356  64148a6f968597fb11a0aaf7
#
#                                                  jobUrl  isFullRemote  \
# 0            Quora-Senior-Android-Engineer---Poe-Remote          True
# 1          GeaCom-Inc-Senior-Software-EngineerTeam-Lead         False
# 2                         Foursquare-Developer-Advocate         False
# 3               Foursquare-Engineering-Manager---Places         False
# 4                         Foursquare-Security-Engineer-         False
# ...                                                 ...           ...
# 2352  Northrop-Grumman-Sr-Principal-Embedded-Softwar...         False
# ...

# %%
data_frame = pd.read_json('./jobs.json')
data_frame
# Out:
#                            _id  \
# 0     6447d95de5702a9c751c8d21
# 1     61b1b3b774413e0016d4e7f1
# 2     62454da3653261babad65676
# 3     62454d9e653261babad6566e
# 4     62454d92653261babad6565d
# ...                        ...
# 2352  64138b6254e25834e3659ad4
# 2353  641474e1968597fb11a0a9df
# 2354  64147677968597fb11a0a9f6
# 2355  641479c2968597fb11a0aa1d
# 2356  64148a6f968597fb11a0aaf7
#
#                                                  jobUrl  isFullRemote  \
# 0            Quora-Senior-Android-Engineer---Poe-Remote          True
# 1          GeaCom-Inc-Senior-Software-EngineerTeam-Lead         False
# 2                         Foursquare-Developer-Advocate         False
# 3               Foursquare-Engineering-Manager---Places         False
# 4                         Foursquare-Security-Engineer-         False
# ...                                                 ...           ...
# 2352  Northrop-Grumman-Sr-Principal-Embedded-Softwar...         False
# ...

# %%
data_frame = pd.read_excel("./jobs.xlsx")
print(data_frame.shape)
# Out:
# (2357, 143)

# %%
data_frame.shape

# %%
data_frame = pd.read_csv("./jobs.csv")
data_frame.iloc[10]
# Out:
# _id                                             62454d23653261babad65607
# jobUrl                     Foursquare--Senior-Software-Engineer---DevOps
# isFullRemote                                                       False
# isPartner                                                            NaN
# companyId                                       624543b75c8eb9c1d2a16e4e
# longitude                                                     -73.991812
# latitude                                                       40.742062
# cityCategory                                               New-York-City
# stateCategory                                                   New-York
# tier                                                                 NaN
# logoImg                                              foursquare-logo.jpg
# activeFrom                                 2023-07-19T14:39:53.722+02:00
# expiresOn                                                            NaN
# ...

# %%
data_frame = pd.read_csv("./jobs.csv")
len(data_frame[data_frame["isFullRemote"]==True])
# Out:
# 115

# %%
len(data_frame[data_frame["stateCategory"]=="New-York"])
# Out:
# 126

# %%
specific_locations = ["New-York","Texas"]
len(data_frame[data_frame["stateCategory"].isin(specific_locations)])
# Out:
# 212

# %%
specific_locations = ["New-York","Texas"]
len(data_frame[data_frame["stateCategory"].str.contains("New-York")])
# Out:
# 126

# %%
sorted_data = data_frame.sort_values(by=["stateCategory"],ascending=False)
sorted_data
# Out:
#                            _id  \
# 426   647f3e61b2b8278440f93fa8
# 2216  641ae718bd0da8caf62d2d4e
# 1250  647f43c4b2b8278440f941b9
# 1474  642ea99d324f6d88c88f5bd1
# 2207  641af89cbd0da8caf62d2e33
# ...                        ...
# 386   64afcbdb028c8e54ddf7cc4d
# 387   64a7f010ac81233fed8b50d4
# 1687  64675e96d68f172584d854fa
# 247   64a7ec33ac81233fed8b504c
# 1983  6422bd7735943444c56cea90
#
#                                                  jobUrl  isFullRemote  \
# 426   Trihydro-Corporation-Software-Developer---Conn...         False
# 2216  Career-Transitions-LLC-Industrial-Electrical-A...         False
# 1250          BlueModus-Inc-Technical-LeadArchitect-NET          True
# 1474  TotalMed-Medfi-IT-Software-Development-Specialist         False
# 2207  Volt-Workforce-Solutions-Sr-Vehicle-Data-Engineer         False
# ...                                                 ...           ...
# 386   Northrop-Grumman-Manager-Software-Engineering-...         False
# ...

# %%
sorted_data = data_frame.sort_index(ascending=True)
sorted_data
# Out:
#                            _id  \
# 0     6447d95de5702a9c751c8d21
# 1     61b1b3b774413e0016d4e7f1
# 2     62454da3653261babad65676
# 3     62454d9e653261babad6566e
# 4     62454d92653261babad6565d
# ...                        ...
# 2352  64138b6254e25834e3659ad4
# 2353  641474e1968597fb11a0a9df
# 2354  64147677968597fb11a0a9f6
# 2355  641479c2968597fb11a0aa1d
# 2356  64148a6f968597fb11a0aaf7
#
#                                                  jobUrl  isFullRemote  \
# 0            Quora-Senior-Android-Engineer---Poe-Remote          True
# 1          GeaCom-Inc-Senior-Software-EngineerTeam-Lead         False
# 2                         Foursquare-Developer-Advocate         False
# 3               Foursquare-Engineering-Manager---Places         False
# 4                         Foursquare-Security-Engineer-         False
# ...                                                 ...           ...
# 2352  Northrop-Grumman-Sr-Principal-Embedded-Softwar...         False
# ...

# %%
edited_data = data_frame.drop(columns=["jobUrl"])
print(len(edited_data.columns))
print(len(data_frame.columns))
# Out:
# 142
# 143

# %%
print(len(edited_data))
print(len(data_frame))
# Out:
# 2357
# 2357

# %%
data_frame.sample(10)
# Out:
#                            _id  \
# 973   6449013dcfbbc38059ae1d88
# 504   6447addcb40e0b0310f8b17c
# 2007  643d50a82b202badf143aab3
# 2078  6424197369b6965923a0c6ba
# 1776  642bfb1471b2a6435ec273d4
# 1936  6447a9d7b40e0b0310f8b138
# 262   647f3254b2b8278440f938e5
# 249   64b668ddbdf597f0230f9334
# 761   646353cf5fcf52152d0c0fe3
# 1493  6475dd0be7fec80779dc4423
#
#                                                  jobUrl  isFullRemote  \
# 973               Ledgent-Technology-Data-Engineer---MN         False
# 504   Northrop-Grumman-Chief-Engineer--ICBM-Sustainment         False
# 2007  Northrop-Grumman-SDS-Principal-Software-System...         False
# 2078  Northrop-Grumman-Principal-RF-Software-Integra...         False
# 1776  Northrop-Grumman-Principal-Integration-and-Tes...         False
# 1936  Northrop-Grumman-Engineer-Systems--Principal-E...         False
# 262   Northrop-Grumman-NC-Programmer-Level-2-or-3-We...         False
# ...

# %%
data_frame.dropna()
# Out:
# Empty DataFrame
# ...

# %%
data_frame.filter(items=["_id","isPartner"])
# Out:
#                            _id isPartner
# 0     6447d95de5702a9c751c8d21     False
# 1     61b1b3b774413e0016d4e7f1       NaN
# 2     62454da3653261babad65676       NaN
# 3     62454d9e653261babad6566e       NaN
# 4     62454d92653261babad6565d       NaN
# ...                        ...       ...
# 2352  64138b6254e25834e3659ad4      True
# 2353  641474e1968597fb11a0a9df      True
# 2354  64147677968597fb11a0a9f6      True
# 2355  641479c2968597fb11a0aa1d      True
# 2356  64148a6f968597fb11a0aaf7      True
#
# [2357 rows x 2 columns]

# %%
specific_data = data_frame[data_frame["stateCategory"].isin(specific_locations)]
specific_data
# Out:
#                            _id  \
# 2     62454da3653261babad65676
# 3     62454d9e653261babad6566e
# 4     62454d92653261babad6565d
# 5     62454d8d653261babad65654
# 6     62454d87653261babad6564c
# 7     62454d7c653261babad6563b
# 8     62454d81653261babad65642
# 9     62454d77653261babad65635
# 10    62454d23653261babad65607
# 11    62454e35653261babad656a7
# 15    6184df2537698300164a96a8
# 27    62a9c1f4ab7cebbb5f540a5d
# 31    62454d97653261babad65665
# 63    624417caf1c665d8cdbf0651
# 68    6358fc4e42a5c7f053e978c9
# 69    635a45b970d0287215a26082
# 70    635a45a970d0287215a26079
# 71    635a458a70d0287215a2606b
# 72    6363c8635f57e8ee9ad8e7a8
# 73    6363c88e5f57e8ee9ad8e7c1
# 80    6376073e22691d6c9cae3d49
# 84    647984b1628a8bc32673821d
# 110   6204351dfbb1d9001657d385
# 111   6273f9d2b3ab9c802f5a9c7f
# 137   610717f54ad9d90015a52700
# 138   610717d94ad9d90015a526fe
# 173   64b1232ada183902df5b6098
# 176   649c0e61db993247ef5a599a
# 246   6488559161d365e0227b9fac
# ...

# %%
sorted_data = data_frame.sort_values(by=["isFullRemote","isPartner"],ascending=False).head(10)
sorted_data
# Out:
#                           _id  \
# 175  64b523ee4a0a0138531ab1b1
# 178  64b523d64a0a0138531ab1ae
# 180  64b523be4a0a0138531ab1aa
# 187  64b5235c4a0a0138531ab19e
# 691  64623cdb615f6b05e64ae2eb
# 720  64b8ef9a905c22bb5cec1efa
# 723  64b8ebcb905c22bb5cec1e91
# 724  64b8ea7f905c22bb5cec1e67
# 727  649451f271b53d6966a2a055
# 730  64b667cfbdf597f0230f9320
#
#                                                 jobUrl  isFullRemote  \
# 175  First-American-Financial-Corporation-Remote-En...          True
# 178  First-American-Financial-Corporation-Principal...          True
# 180  First-American-Financial-Corporation-Lead-DevO...          True
# 187  First-American-Financial-Corporation-Sr-Site-R...          True
# 691                        ICF-Sr-ServiceNow-Developer          True
# 720                  Medasource-Lead-Software-Engineer          True
# 723  OneStream-Senior-Software-Quality-Assurance-En...          True
# 724                 OneStream-Senior-Software-Engineer          True
# ...

# %%
indexed_data_frame = pd.read_csv("./jobs.csv",index_col="cityCategory")
indexed_data_frame
# Out:
#                                     _id  \
# cityCategory
# San-Jose       6447d95de5702a9c751c8d21
# Duluth         61b1b3b774413e0016d4e7f1
# New-York-City  62454da3653261babad65676
# New-York-City  62454d9e653261babad6566e
# New-York-City  62454d92653261babad6565d
# ...                                 ...
# Los-Angeles    64138b6254e25834e3659ad4
# New-York-City  641474e1968597fb11a0a9df
# Biloxi         64147677968597fb11a0a9f6
# Los-Angeles    641479c2968597fb11a0aa1d
# Cincinnati     64148a6f968597fb11a0aaf7
#
#                                                           jobUrl  \
# cityCategory
# San-Jose              Quora-Senior-Android-Engineer---Poe-Remote
# Duluth              GeaCom-Inc-Senior-Software-EngineerTeam-Lead
# New-York-City                      Foursquare-Developer-Advocate
# New-York-City            Foursquare-Engineering-Manager---Places
# New-York-City                      Foursquare-Security-Engineer-
# ...

# %%
# indexed_data_frame.set_index(["jobUrl"],inplace=True)
# indexed_data_frame.sort_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22896\2854350750.py in ?()
# ----> 1 indexed_data_frame.set_index(["jobUrl"],inplace=True)
#       2 indexed_data_frame.sort_index()
#
# ~\Desktop\all projects\python-projects\numpy-reminder\.venv\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['jobUrl'] are in the columns"

# %%
data_frame = pd.read_csv("./jobs.csv")
grouped_data_frame=data_frame.groupby("longitude")
grouped_data_frame

# %%
grouped_data_frame.tail(5)
# Out:
#                            _id  \
# 0     6447d95de5702a9c751c8d21
# 1     61b1b3b774413e0016d4e7f1
# 8     62454d81653261babad65642
# 9     62454d77653261babad65635
# 10    62454d23653261babad65607
# ...                        ...
# 2352  64138b6254e25834e3659ad4
# 2353  641474e1968597fb11a0a9df
# 2354  64147677968597fb11a0a9f6
# 2355  641479c2968597fb11a0aa1d
# 2356  64148a6f968597fb11a0aaf7
#
#                                                  jobUrl  isFullRemote  \
# 0            Quora-Senior-Android-Engineer---Poe-Remote          True
# 1          GeaCom-Inc-Senior-Software-EngineerTeam-Lead         False
# 8                        Foursquare-Senior-iOS-Engineer         False
# 9                     Foursquare-Senior-Mobile-Engineer         False
# 10        Foursquare--Senior-Software-Engineer---DevOps         False
# ...                                                 ...           ...
# 2352  Northrop-Grumman-Sr-Principal-Embedded-Softwar...         False
# ...

# %%
grouped_data_frame.head(5)
# Out:
#                            _id  \
# 0     6447d95de5702a9c751c8d21
# 1     61b1b3b774413e0016d4e7f1
# 2     62454da3653261babad65676
# 3     62454d9e653261babad6566e
# 4     62454d92653261babad6565d
# ...                        ...
# 2344  64148075968597fb11a0aa7b
# 2345  64148c57968597fb11a0ab0e
# 2348  64149d02968597fb11a0abc2
# 2353  641474e1968597fb11a0a9df
# 2354  64147677968597fb11a0a9f6
#
#                                                  jobUrl  isFullRemote  \
# 0            Quora-Senior-Android-Engineer---Poe-Remote          True
# 1          GeaCom-Inc-Senior-Software-EngineerTeam-Lead         False
# 2                         Foursquare-Developer-Advocate         False
# 3               Foursquare-Engineering-Manager---Places         False
# 4                         Foursquare-Security-Engineer-         False
# ...                                                 ...           ...
# 2344                         AppleOne-Program-Developer         False
# ...

# %%
grouped_data_frame.size()
# Out:
# longitude
# -157.862290    3
# -155.091005    1
# -149.739605    2
# -147.099444    1
# -123.191453    1
#               ..
# -71.030021     1
# -70.667385     1
# -68.196315     1
#  4.376211      1
#  6.629457      1
# Length: 986, dtype: int64

# %%
grouped_data_frame.agg({"longitude":["mean","max","min"],"latitude":["mean","max","min"]})
# Out:
#               longitude                           latitude             \
#                    mean         max         min       mean        max
# longitude
# -157.862290 -157.862290 -157.862290 -157.862290  21.297426  21.297426
# -155.091005 -155.091005 -155.091005 -155.091005  19.726483  19.726483
# -149.739605 -149.739605 -149.739605 -149.739605  61.210032  61.210032
# -147.099444 -147.099444 -147.099444 -147.099444  64.664444  64.664444
# -123.191453 -123.191453 -123.191453 -123.191453  44.052851  44.052851
# ...                 ...         ...         ...        ...        ...
# -71.030021   -71.030021  -71.030021  -71.030021  42.344256  42.344256
# -70.667385   -70.667385  -70.667385  -70.667385  41.958380  41.958380
# -68.196315   -68.196315  -68.196315  -68.196315  44.365255  44.365255
#  4.376211      4.376211    4.376211    4.376211  51.998565  51.998565
#  6.629457      6.629457    6.629457    6.629457  46.515903  46.515903
#
#
#                    min
# longitude
# ...

# %%
grouped_data_frame.describe()
# Out:
#             latitude                                                   \
#                count       mean  std        min        25%        50%
# longitude
# -157.862290      3.0  21.297426  0.0  21.297426  21.297426  21.297426
# -155.091005      1.0  19.726483  NaN  19.726483  19.726483  19.726483
# -149.739605      2.0  61.210032  0.0  61.210032  61.210032  61.210032
# -147.099444      1.0  64.664444  NaN  64.664444  64.664444  64.664444
# -123.191453      1.0  44.052851  NaN  44.052851  44.052851  44.052851
# ...              ...        ...  ...        ...        ...        ...
# -71.030021       1.0  42.344256  NaN  42.344256  42.344256  42.344256
# -70.667385       1.0  41.958380  NaN  41.958380  41.958380  41.958380
# -68.196315       1.0  44.365255  NaN  44.365255  44.365255  44.365255
#  4.376211        1.0  51.998565  NaN  51.998565  51.998565  51.998565
#  6.629457        1.0  46.515903  NaN  46.515903  46.515903  46.515903
#
# ...

# %%
grouped_data_frame["latitude"].describe()
# Out:
#              count       mean  std        min        25%        50%  \
# longitude
# -157.862290    3.0  21.297426  0.0  21.297426  21.297426  21.297426
# -155.091005    1.0  19.726483  NaN  19.726483  19.726483  19.726483
# -149.739605    2.0  61.210032  0.0  61.210032  61.210032  61.210032
# -147.099444    1.0  64.664444  NaN  64.664444  64.664444  64.664444
# -123.191453    1.0  44.052851  NaN  44.052851  44.052851  44.052851
# ...            ...        ...  ...        ...        ...        ...
# -71.030021     1.0  42.344256  NaN  42.344256  42.344256  42.344256
# -70.667385     1.0  41.958380  NaN  41.958380  41.958380  41.958380
# -68.196315     1.0  44.365255  NaN  44.365255  44.365255  44.365255
#  4.376211      1.0  51.998565  NaN  51.998565  51.998565  51.998565
#  6.629457      1.0  46.515903  NaN  46.515903  46.515903  46.515903
#
#                    75%        max
# longitude
# -157.862290  21.297426  21.297426
# -155.091005  19.726483  19.726483
# ...

# %%
data_frame = pd.read_csv("./Employee Sample Data.csv")
data_frame
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age   Hire Date Annual Salary  \
# 0    Research & Development  Female      Black   55    4/8/2016     $141,604
# ...

# %%
data_frame["Full Name"]
# Out:
# 0          Emily Davis
# 1        Theodore Dinh
# 2         Luna Sanders
# 3      Penelope Jordan
# 4            Austin Vo
#             ...
# 995       Wesley Young
# 996       Lillian Khan
# 997        Oliver Yang
# 998        Lily Nguyen
# 999        Sofia Cheng
# Name: Full Name, Length: 1000, dtype: object

# %%
data_frame["Age"]
# Out:
# 0      55
# 1      59
# 2      50
# 3      26
# 4      55
#        ..
# 995    33
# 996    44
# 997    31
# 998    33
# 999    63
# Name: Age, Length: 1000, dtype: int64

# %%
ages = data_frame[data_frame["Age"] <= 50]
ages
# Out:
#        EEID          Full Name                 Job Title  Department  \
# 2    E02572       Luna Sanders                  Director     Finance
# 3    E02832    Penelope Jordan  Computer Systems Manager          IT
# 6    E01550        Ruby Barnes                   Manager          IT
# 7    E04332        Luke Martin                   Analyst     Finance
# 8    E04533      Easton Bailey                   Manager  Accounting
# ..      ...                ...                       ...         ...
# 993  E04762  Audrey Richardson                  Director          IT
# 995  E03094       Wesley Young               Sr. Analyst   Marketing
# 996  E01909       Lillian Khan                   Analyst     Finance
# 997  E04398        Oliver Yang                  Director   Marketing
# 998  E02521        Lily Nguyen               Sr. Analyst     Finance
#
#            Business Unit  Gender  Ethnicity  Age   Hire Date Annual Salary  \
# ...

# %%
jobs_title = data_frame["Job Title"]
jobs_title
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Desktop\all projects\python-projects\numpy-reminder\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Job Title'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[62], line 1
# ...

# %%
hire_dates = data_frame[pd.to_datetime(data_frame["Hire Date"])< "4/8/2016"]
hire_dates
# Out:
#        EEID       Full Name             Job Title       Department  \
# 1    E04105   Theodore Dinh   Technical Architect               IT
# 2    E02572    Luna Sanders              Director          Finance
# 4    E01639       Austin Vo           Sr. Analyst          Finance
# 10   E00591    Savannah Ali            Sr. Manger  Human Resources
# 12   E00530       Eli Jones               Manager  Human Resources
# ..      ...             ...                   ...              ...
# 991  E03430     Leo Herrera  Sr. Business Partner  Human Resources
# 992  E03058   Robert Wright   Technical Architect               IT
# 994  E01148  Scarlett Kumar       Systems Analyst               IT
# 996  E01909    Lillian Khan               Analyst          Finance
# 998  E02521     Lily Nguyen           Sr. Analyst          Finance
#
#               Business Unit  Gender  Ethnicity  Age   Hire Date Annual Salary  \
# 1             Manufacturing    Male      Asian   59  11/29/1997      $99,975
# ...

# %%
dates_split = hire_dates.str.split("/")
dates_split
# Out:
# 0        [4, 8, 2016]
# 1      [11, 29, 1997]
# 2      [10, 26, 2006]
# 3       [9, 27, 2019]
# 4      [11, 20, 1995]
#             ...
# 995     [9, 18, 2016]
# 996     [5, 31, 2010]
# 997     [6, 10, 2019]
# 998     [1, 28, 2012]
# 999     [7, 26, 2020]
# Name: Hire Date, Length: 1000, dtype: object

# %%
days,months,years = dates_split[0]
print(days,months,years)
# Out:
# 4 8 2016

# %%
annual_salaries = data_frame["Annual Salary"]
annual_salaries
# Out:
# 0      $141,604
# 1       $99,975
# 2      $163,099
# 3       $84,913
# 4       $95,409
#          ...
# 995     $98,427
# 996     $47,387
# 997    $176,710
# 998     $95,960
# 999    $216,195
# Name: Annual Salary, Length: 1000, dtype: object

# %%
numeric_annual_salaries = pd.to_numeric(annual_salaries.str.replace(r"[$,]","",regex=True).astype(float))
numeric_annual_salaries
# Out:
# 0      141604.0
# 1       99975.0
# 2      163099.0
# 3       84913.0
# 4       95409.0
#          ...
# 995     98427.0
# 996     47387.0
# 997    176710.0
# 998     95960.0
# 999    216195.0
# Name: Annual Salary, Length: 1000, dtype: float64

# %%
numeric_annual_salaries.plot(kind="bar",figsize=(10,5),title="Annual Salary",xlabel="count",ylabel="Annual Salary")
# Out:
# <Axes: title={'center': 'Annual Salary'}, xlabel='count', ylabel='Annual Salary'>

# %%
males_salaries = data_frame[data_frame["Gender"]=="Male"]["Annual Salary"].str.replace(r"[$,]","",regex=True).astype(float)
females_salaries = data_frame[data_frame["Gender"]=="Female"]["Annual Salary"].str.replace(r"[$,]","",regex=True).astype(float)
males_salaries.plot(xlabel="count (person)",ylabel="yearly salary ($)",title="salary per count",figsize=(15,10))
females_salaries.plot(xlabel="count (person)",ylabel="yearly salary ($)",title="salary per count",figsize=(15,10))
# Out:
# <Axes: title={'center': 'salary per count'}, xlabel='count (person)', ylabel='yearly salary ($)'>

# %%
males_salaries = data_frame[data_frame["Gender"] == "Male"]["Annual Salary"].str.replace(r"[$,]", "",regex=True).astype(float)
females_salaries = data_frame[data_frame["Gender"] == "Female"]["Annual Salary"].str.replace(r"[$,]", "",regex=True).astype(float)
males_salaries/=12
females_salaries/=12
males_salaries.sample(20).plot(xlabel="count (person)", ylabel="monthly salary ($)", title="salary per count",figsize=(15,10),kind="line")
females_salaries.sample(20).plot(xlabel="count (person)", ylabel="monthly salary ($)", title="salary per count",figsize=(15,10),kind="line")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Desktop\all projects\python-projects\reminder\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Gender'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ...

# %%
plt.xlabel("salaries")
plt.ylabel("count")
plt.title("salary per count")
plt.plot(males_salaries[0:100],np.arange(100),label="male salaries",linestyle="dashed")
plt.plot(females_salaries[0:100],np.arange(100),label="females salaries",linestyle="dashed")
plt.legend()
plt.grid()

# %%
plt.xlabel("salaries")
plt.ylabel("count")
plt.title("salary per count")
plt.hist(males_salaries[0:100],np.arange(100),label="male salaries",linestyle="dashed")
plt.hist(females_salaries[0:100],np.arange(100),label="females salaries",linestyle="dashed")
plt.legend()
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       2 plt.ylabel("count")
#       3 plt.title("salary per count")
# ----> 4 plt.hist(males_salaries[0:100],np.arange(100),label="male salaries",linestyle="dashed")
#       5 plt.hist(females_salaries[0:100],np.arange(100),label="females salaries",linestyle="dashed")
#       6 plt.legend()
#
# NameError: name 'males_salaries' is not defined

# %%
plt.xlabel("")
plt.ylabel("")
plt.title("salary per count")
plt.pie(males_salaries[0:100],labels=np.arange(100))
plt.pie(females_salaries[0:100],labels=np.arange(100))
plt.legend()
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 plt.ylabel("")
#       3 plt.title("salary per count")
# ----> 4 plt.pie(males_salaries[0:100],labels=np.arange(100))
#       5 plt.pie(females_salaries[0:100],labels=np.arange(100))
#       6 plt.legend()
#
# NameError: name 'males_salaries' is not defined
